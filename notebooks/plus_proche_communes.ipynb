# %%
from dgfip.read import get_com
com = get_com(compute_distance=True)

# %%
ax = com.plot.scatter(x='distance Centre de Finances publiques', y= 'MED17')
ax.set_title('Revenu médian communale vs Distance')
# Out:
# Text(0.5, 1.0, 'Revenu médian communale vs Distance')
